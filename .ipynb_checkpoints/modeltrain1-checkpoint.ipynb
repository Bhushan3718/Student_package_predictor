# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#understand the problem statement
#data collection

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.scatter(df['cgpa'],df['package'])

# %%
import seaborn as sns
sns.boxplot(df['package'])
# Out:
# <Axes: ylabel='package'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['cgpa']],df[['package']],test_size=0.3,random_state=40)

# %%
x_train
# Out:
#      cgpa
# 188  7.35
# 170  6.22
# 107  6.33
# 65   7.60
# 109  7.77
# ..    ...
# 50   9.58
# 184  7.88
# 165  8.21
# 7    6.75
# 70   5.79
#
# [140 rows x 1 columns]

# %%
x_test.shape
# Out:
# (60, 1)

# %%
x_test
# Out:
#      cgpa
# 96   7.11
# 5    7.89
# 116  9.04
# 35   6.87
# 183  7.28
# 160  7.13
# 54   6.86
# 134  7.20
# 90   7.11
# 191  7.28
# 139  7.19
# 142  6.93
# 177  7.09
# 26   8.31
# 89   6.42
# 140  7.91
# 171  8.01
# 23   6.19
# 132  5.84
# 37   5.90
# 151  6.12
# 28   5.94
# 85   4.79
# 93   6.79
# 174  7.32
# 75   6.97
# 18   6.94
# 105  6.66
# 121  6.50
# 130  6.68
# 33   6.35
# 46   6.07
# 168  8.65
# 169  9.31
# 11   6.61
# 166  8.60
# 81   6.10
# 111  5.42
# 67   6.51
# 147  5.66
# 86   7.61
# 182  5.88
# 69   7.30
# 125  7.33
# 42   5.95
# 77   8.99
# 62   6.34
# 154  7.08
# 59   7.56
# 148  7.57
# 175  7.04
# 24   6.53
# 143  4.85
# 64   7.36
# 196  5.89
# 40   9.38
# 112  8.58
# 52   8.37
# 145  5.84
# 136  5.64

# %%
x_test.shape
# Out:
# (60, 1)

# %%
#model Training
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.7783623334181906

# %%
model.predict([[7.8]])
# Out:
# C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.49829943]])

# %%
model.predict([[6.89]])
# Out:
# C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.97091408]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,model.predict(x_train),color="red")

# %%
x_train
# Out:
#      cgpa
# 188  7.35
# 170  6.22
# 107  6.33
# 65   7.60
# 109  7.77
# ..    ...
# 50   9.58
# 184  7.88
# 165  8.21
# 7    6.75
# 70   5.79
#
# [140 rows x 1 columns]

# %%
x_test
# Out:
#      cgpa
# 96   7.11
# 5    7.89
# 116  9.04
# 35   6.87
# 183  7.28
# 160  7.13
# 54   6.86
# 134  7.20
# 90   7.11
# 191  7.28
# 139  7.19
# 142  6.93
# 177  7.09
# 26   8.31
# 89   6.42
# 140  7.91
# 171  8.01
# 23   6.19
# 132  5.84
# 37   5.90
# 151  6.12
# 28   5.94
# 85   4.79
# 93   6.79
# 174  7.32
# 75   6.97
# 18   6.94
# 105  6.66
# 121  6.50
# 130  6.68
# 33   6.35
# 46   6.07
# 168  8.65
# 169  9.31
# 11   6.61
# 166  8.60
# 81   6.10
# 111  5.42
# 67   6.51
# 147  5.66
# 86   7.61
# 182  5.88
# 69   7.30
# 125  7.33
# 42   5.95
# 77   8.99
# 62   6.34
# 154  7.08
# 59   7.56
# 148  7.57
# 175  7.04
# 24   6.53
# 143  4.85
# 64   7.36
# 196  5.89
# 40   9.38
# 112  8.58
# 52   8.37
# 145  5.84
# 136  5.64

# %% [markdown]
# # Train Acc

# %%
from sklearn.metrics import r2_score

# %%
y_train_pred=model.predict(x_train)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.7783623334181906

# %% [markdown]
# # Test Acc

# %%
y_test_pred=model.predict(x_test)

# %%
r2_score(y_test,y_test_pred)
# Out:
# 0.7519705464243485

# %%
print(dir(model))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__sklearn_clone__', '__sklearn_tags__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_decision_function', '_doc_link_module', '_doc_link_template', '_doc_link_url_param_generator', '_get_class_level_metadata_request_values', '_get_doc_link', '_get_metadata_request', '_get_param_names', '_get_params_html', '_html_repr', '_parameter_constraints', '_repr_html_', '_repr_html_inner', '_repr_mimebundle_', '_set_intercept', '_validate_params', 'coef_', 'copy_X', 'feature_names_in_', 'fit', 'fit_intercept', 'get_metadata_routing', 'get_params', 'intercept_', 'n_features_in_', 'n_jobs', 'positive', 'predict', 'rank_', 'score', 'set_fit_request', 'set_params', 'set_score_request', 'singular_', 'tol']

# %% [markdown]
# # y=m*x+c

# %%
m=model.coef_
m
# Out:
# array([[0.57954434]])

# %%
c=model.intercept_
c
# Out:
# array([-1.02214643])

# %%
x=[[8.6]]
model.predict(x)
# Out:
# C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.9619349]])

# %%
y=m*x+c
y
# Out:
# array([[3.9619349]])

# %%
# How to  use this predicted file  in diffrent place

# %%
#save a file  in a binary 
#pickel and joblib

# %%
! pip install joblib
# Out:
# Requirement already satisfied: joblib in C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.5.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib

# %%
# save a model 
joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %%
# load the model 
model1=joblib.load("model.joblib")

# %%
model1.predict([[8.6]])
# Out:
# C:\Users\Bhushan Arvind Patil\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.9619349]])

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Bhushan Arvind Patil\\Desktop\\IT Vedant\\Machine Learning\\Models'
